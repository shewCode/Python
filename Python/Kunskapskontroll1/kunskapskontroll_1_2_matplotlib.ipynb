# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %%
#import numpy as np är rekommenderat

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %%
# "Figure" är hela bilden eller container där hela plot eller visualisering skapas. Man kan ha flera subplots eller axes
# "Axes" är ett område inom "Figure". där data läggs ut. När man skapar en plot via "method" från axlar så kan man anpassa och lägga till data
# "Axis" representerar x och y axlar och ibland z i plot. Dom styr "tick labels" markeringarna, värden och axis begränsingar så
# att man kan definera skalan och utseendet på plot.
# "Artist" representerar individuella visuella element som linjer, text, former och bilder. Man kan
# manipulera "artist" för att anpassa utseendet på sina plot i detalj.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %%
# Matplotlib är en python bibliotek som är till för att skapa grafer så vanligtvis är input data typer som int och float
# om representerar värden för plotting,till exempel till olika typer av grafer förväntat.

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
# Object-oriented approach

#genererar x
x = np.linspace(-4, 4, 100)
#kalkylerar y värdet
y = x**2
# skapa figure och axis
fig, ax = plt.subplots()
# skapa grafen, plot
ax.plot(x, y)
#Titel
ax.set_title("y = x^2")
ax.set_xlabel("x")
ax.set_ylabel("y")
# Visa grafen
plt.show()

# %%
# Pyplot approach
x = np.linspace(-4, 4, 100)
y = x**2
plt.plot(x, y)
# skapar titel och axis-labels
plt.title("y = x^2")
plt.xlabel("x")
plt.ylabel("y")
# Visa grafen
plt.show()

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
# skapar subplots
fig, ax = plt.subplots(1, 2, layout='constrained')
# Scatter plot
ax[0].scatter(random_data_x, random_data_y)
ax[0].set_title('Scatter plot')
ax[0].set_xlabel('x')
ax[0].set_ylabel('y')
# Bar plot
ax[1].bar(names, values)
ax[1].set_title('Bar plot')
ax[1].set_xlabel('fruit')
ax[1].set_ylabel('value')
plt.show()
